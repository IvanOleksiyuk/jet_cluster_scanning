# %%
import numpy as np
import scipy.stats as sts
from matplotlib import pyplot as plt
from scipy.special import gammainc

# %%
data_path="../../../DATA/LHCO/"
mjj_bg = np.load(data_path+"mjj_bkg_sort.npy")
mjj_sg = np.load(data_path+"mjj_sig_sort.npy")

# %%
hist_bg = plt.hist(mjj_bg, bins=16, range=(3000, 4600), histtype='step')
hist_sg = plt.hist(mjj_sg, bins=16, range=(3000, 4600), histtype='step')
x = np.linspace(3000+50, 4600-50, 16)
hist_bg=hist_bg[0]
hist_sg=hist_sg[0]

# %%
sg_frac = 0.025
true_frac = np.sum(sg_frac*hist_sg)/np.sum(sg_frac*hist_sg + hist_bg)
true_frac
# Out:
# 0.0062852028161596235

# %%
sigma_bg=np.sqrt(hist_bg)
plt.step(x, hist_bg, where='mid', color="blue")
plt.errorbar(x, hist_bg, yerr=np.sqrt(hist_bg)*3 ,linestyle="", color="blue")
plt.step(x, hist_bg+hist_sg*sg_frac, where='mid', color="red")

# %%
plt.step(x, hist_sg*sg_frac, where='mid', color="red")
plt.errorbar(x, x*0, yerr=sigma_bg ,linestyle="", color="blue")
plt.grid()

# %%
plt.step(x, hist_sg*sg_frac/sigma_bg, where='mid', color="red")

# %%
max_dev_sig=np.max(hist_sg*sg_frac/sigma_bg)
max_dev_sig
# Out:
# 3.774913117504191

# %%
p_value = sts.norm.sf(max_dev_sig)
p_value
# Out:
# 8.003172054130478e-05

# %%
p_global=1-(1-p_value)**16
p_global
# Out:
# 0.0012797392064918256

# %%
s_global=-sts.norm.ppf(p_global)

# %%
n_bootstraps = 1000

bootstrap_bg = np.random.choice(mjj_bg, size=(n_bootstraps, len(mjj_bg)))
len(bootstrap_bg[0])

#max_devs=np.array(max_devs)
#plt.hist(max_devs, bins=100, range=(0, 10), histtype='step')
# Out:
# 1000000

# %%
max_devs=[]
for i in range(n_bootstraps):
	hist_bg_boot = np.histogram(bootstrap_bg[i], bins=16, range=(3000, 4600))
	hist_bg_boot = hist_bg_boot[0]
	max_dev=np.max((hist_bg_boot-hist_bg)/sigma_bg)
	max_devs.append(max_dev)
max_devs=np.array(max_devs)

# %%
plt.hist(max_devs, bins=100, range=(0, 10), histtype='step')
plt.axvline(max_dev_sig, color="red")
print(np.sum(max_devs>max_dev_sig)/n_bootstraps)
# Out:
# 0.0

# %%
def get_hunter_scheme(hunter) -> np.ndarray:
    if hunter.str_scale == "lin":
        sig_str = np.arange(
            hunter.str_min,
            hunter.str_min + hunter.str_step * len(hunter.sigma_ar),
            step=hunter.str_step,
        )
    else:
        sig_str = np.array(
            [
                i % 10 * 10 ** (hunter.str_min + i // 10)
                for i in range(len(hunter.sigma_ar) + len(hunter.sigma_ar) // 10 + 1)
                if i % 10 != 0
            ]
        )
    return sig_str

# %%
 # Create a BumpHunter1D class instance
import pyBumpHunter as BH
hunter = BH.BumpHunter1D(
    rang=[3000, 4600],
    width_min=2,
    width_max=10,
    width_step=2,
    scan_step=1,
    npe=100000,
    nworker=6,
    seed=42,
    use_sideband=True,
    str_min=-5,
    sigma_limit=8,
    str_scale="log",
    bins=np.linspace(3000, 4600, 17)
)

# Run the bump hunter without any cuts
hunter.signal_inject(mjj_bg, mjj_sg)
raw_str = get_hunter_scheme(hunter)
raw_sens = hunter.sigma_ar.copy()
min_l = min(len(raw_sens), len(raw_str))  # Sometimes the hunter lengths dont match
raw_sens = raw_sens[:min_l]
raw_str = raw_str[:min_l]
# Out:
# Generating background only histograms
# 5 values of width will be tested
# BACKGROUND ONLY SCAN
# STARTING INJECTION
#    STEP 1 : signal strength = 1e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5197  (51966 / 100000)   0.8444  (84438)   0.2022  (20220)
# Significance = -0.04930 (-1.01262  0.83379)
#
#    STEP 2 : signal strength = 2e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.4331  (43307 / 100000)   0.8327  (83269)   0.2031  (20314)
# Significance = 0.16856 (-0.96485  0.83046)
#
#    STEP 3 : signal strength = 3.0000000000000004e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.4805  (48054 / 100000)   0.8937  (89372)   0.1334  (13337)
# Significance = 0.04880 (-1.24656  1.11060)
#
#    STEP 4 : signal strength = 4e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5344  (53442 / 100000)   0.8358  (83585)   0.1657  (16570)
# Significance = -0.08639 (-0.97754  0.97130)
#
#    STEP 5 : signal strength = 5e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.4721  (47212 / 100000)   0.8682  (86820)   0.1320  (13202)
# Significance = 0.06994 (-1.11792  1.11689)
#
#    STEP 6 : signal strength = 6e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5480  (54803 / 100000)   0.8803  (88034)   0.2631  (26314)
# Significance = -0.12069 (-1.17669  0.63369)
#
#    STEP 7 : signal strength = 7.000000000000001e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5640  (56403 / 100000)   0.8642  (86416)   0.2376  (23755)
# Significance = -0.16119 (-1.09920  0.71421)
#
#    STEP 8 : signal strength = 8e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5039  (50385 / 100000)   0.8316  (83159)   0.1711  (17105)
# Significance = -0.00965 (-0.96047  0.95002)
#
#    STEP 9 : signal strength = 9e-05
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5224  (52236 / 100000)   0.8671  (86709)   0.1464  (14639)
# Significance = -0.05608 (-1.11274  1.05204)
#
#    STEP 10 : signal strength = 0.0001
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.4859  (48592 / 100000)   0.8644  (86442)   0.2155  (21553)
# Significance = 0.03530 (-1.10040  0.78738)
#
#    STEP 11 : signal strength = 0.0002
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.6028  (60275 / 100000)   0.8308  (83085)   0.2305  (23052)
# Significance = -0.26047 (-0.95753  0.73714)
#
#    STEP 12 : signal strength = 0.00030000000000000003
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7144  (71439 / 100000)   0.9105  (91054)   0.2783  (27835)
# Significance = -0.56626 (-1.34409  0.58775)
#
#    STEP 13 : signal strength = 0.0004
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7087  (70865 / 100000)   0.9060  (90601)   0.3489  (34894)
# Significance = -0.54945 (-1.31658  0.38818)
#
#    STEP 14 : signal strength = 0.0005
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7420  (74202 / 100000)   0.9144  (91440)   0.3559  (35593)
# Significance = -0.64959 (-1.36836  0.36936)
#
#    STEP 15 : signal strength = 0.0006000000000000001
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7010  (70099 / 100000)   0.8949  (89485)   0.3719  (37194)
# Significance = -0.52725 (-1.25274  0.32672)
#
#    STEP 16 : signal strength = 0.0007000000000000001
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7960  (79599 / 100000)   0.9271  (92714)   0.6107  (61068)
# Significance = -0.82738 (-1.45482  -0.28109)
#
#    STEP 17 : signal strength = 0.0008000000000000001
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.8077  (80769 / 100000)   0.9326  (93259)   0.6478  (64784)
# Significance = -0.86942 (-1.49536  -0.37950)
#
#    STEP 18 : signal strength = 0.0009000000000000002
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7362  (73621 / 100000)   0.8734  (87342)   0.5298  (52980)
# Significance = -0.63170 (-1.14271  -0.07477)
#
#    STEP 19 : signal strength = 0.0010000000000000002
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.7529  (75287 / 100000)   0.8837  (88365)   0.6109  (61087)
# Significance = -0.68355 (-1.19343  -0.28159)
#
#    STEP 20 : signal strength = 0.002
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.6217  (62169 / 100000)   0.7376  (73764)   0.5244  (52444)
# Significance = -0.30992 (-0.63609  -0.06130)
#
#    STEP 21 : signal strength = 0.003
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.5086  (50856 / 100000)   0.5782  (57822)   0.4166  (41662)
# Significance = -0.02146 (-0.19734  0.21055)
#
#    STEP 22 : signal strength = 0.004
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.3944  (39441 / 100000)   0.4683  (46832)   0.3197  (31969)
# Significance = 0.26784 (0.07949  0.46857)
#
#    STEP 23 : signal strength = 0.005
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.3013  (30126 / 100000)   0.3708  (37078)   0.2585  (25850)
# Significance = 0.52078 (0.32979  0.64798)
#
#    STEP 24 : signal strength = 0.006
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.2185  (21848 / 100000)   0.2674  (26738)   0.1705  (17051)
# Significance = 0.77734 (0.62076  0.95215)
#
#    STEP 25 : signal strength = 0.007
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.1539  (15391 / 100000)   0.1983  (19829)   0.1218  (12180)
# Significance = 1.01981 (0.84774  1.16604)
#
#    STEP 26 : signal strength = 0.008
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.1171  (11705 / 100000)   0.1498  (14984)   0.0923  (9230)
# Significance = 1.18986 (1.03712  1.32672)
#
#    STEP 27 : signal strength = 0.009000000000000001
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.0780  (7804 / 100000)   0.1007  (10068)   0.0608  (6084)
# Significance = 1.41838 (1.27769  1.54776)
#
#    STEP 28 : signal strength = 0.010000000000000002
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.0558  (5580 / 100000)   0.0766  (7664)   0.0403  (4031)
# Significance = 1.59104 (1.42804  1.74710)
#
#    STEP 29 : signal strength = 0.020000000000000004
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.0005  (54 / 100000)   0.0008  (81)   0.0004  (37)
# Significance = 3.26881 (3.15228  3.37431)
#
#    STEP 30 : signal strength = 0.030000000000000006
# Generating background+signal histograms
# BACKGROUND+SIGNAL SCAN
# Global p-value : 0.0000  (1 / 100000)   0.0000  (1)   0.0000  (0)
# Significance = 4.26489 (4.26489  4.26489)
#
# REACHED STAT LIMIT AT 4.265 SIGMA
#    Number of signal event injected : 30000.000000000007
#    Signal strength : 0.0300

# %%
# Create the figure
fig = plt.figure(figsize=(5, 5))
plt.errorbar(
    raw_str,
    raw_sens[:, 0],
    xerr=0,
    yerr=[raw_sens[:, 1], raw_sens[:, 2]],
    marker="x",
    color="k",
    uplims=raw_sens[:, 2] == 0,
    label="raw data",
)
plt.plot([0.005, 0.0025], [3.21, 0.92], color="red")
plt.scatter([sg_frac*0.1], [s_global], color="blue")
